# %%
import psycopg2
conn = psycopg2.connect(host = "34.125.207.114", dbname="game", user="postgres", password="1234", port=5432)
cur = conn.cursor()

cur.execute('''
                CREATE TABLE IF NOT EXISTS metacritic_game (id SERIAL PRIMARY KEY,
                                                name VARCHAR,
                                                platform VARCHAR,
                                                publisher VARCHAR,
                                                rating VARCHAR,
                                                genre VARCHAR,
                                                _of_player VARCHAR,
                                                release_date VARCHAR,
                                                critic_score NUMERIC,
                                                critic_count NUMERIC,
                                                user_score NUMERIC,
                                                user_count NUMERIC,
                                                img_url VARCHAR,
                                                description VARCHAR);          
            ''')
conn.commit()

# %%
cur.execute("DROP TABLE metacritic_game")
conn.commit()

# %%
from sqlalchemy import create_engine
import pandas as pd

df = pd.read_csv('/opt/ml/lv3/postgre/after_preprocess/preprocess_raw.csv')
engine = create_engine("postgresql://postgres:1234@34.125.207.114:5432/game")
df.to_sql("metacritic_game", engine, if_exists="append", index=False)
# Out:
# 904

# %%
from sqlalchemy import create_engine
import pandas as pd
engine = create_engine("postgresql://postgres:1234@34.125.207.114:5432/game")
game_table = "metacritic_game"
pdata = pd.read_sql_table(table_name=game_table, con=engine)

# %%
pdata.head()
# Out:
#    id             name       platform                publisher rating  \
# 0   1           #DRIVE         Switch          PM Studios Inc.    all
# 1   2           #IDARB       Xbox One  Other Ocean Interactive    all
# 2   3  #KILLALLZOMBIES       Xbox One    Digerati Distribution    13+
# 3   4    'Splosion Man       Xbox 360      Twisted Pixel Games    10+
# 4   5         .detuned  PlayStation 3                     SCEA    all
#
#                                                genre             _of_player  \
# 0                 ['Racing', 'Arcade', 'Automobile']  No Online Multiplayer
# 1  ['Action', 'Miscellaneous', 'General', 'Party ...             At Least 1
# 2  ['Action', 'Shooter', "Shoot-'Em-Up", 'Top-Down']  No Online Multiplayer
# 3  ['Action', 'General', 'Platformer', 'Platforme...              4  Online
# 4  ['Action', 'Miscellaneous', 'Rhythm', 'Music',...               1 Player
#
#    release_date  critic_score  critic_count  user_score  user_count  \
# ...
